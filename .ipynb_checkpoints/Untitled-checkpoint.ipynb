# %%
from pension import Liabilities
from portfolio import *
from cma import *

# %%
l = Liabilities(
    retired_members=RETIRED_MEMBERS,
    active_members=ACTIVE_MEMBERS,
    average_salary=AVG_SALARY,
    min_active_members=MIN_ACTIVE_MEMBERS,
    active_members_decline=ACTIVE_MEMBER_DECLINE,
    retired_members_growth=RETIRED_MEMBERS_GROWTH,
    wage_growth_rate=WAGE_GROWTH,
    starting_duration=INITIAL_DURATION,
    actuarial_df=ACTUARIAL_DF,
    service_cost=SERVICE_COST_RATE,
    starting_liabilities=LIABILITIES,
    starting_benefit=STARTING_BENEFIT,
    benefit_growth_rate=BENEFIT_GROWTH_RATE,
    liabilities_cache={}
)

# %%
l.get_closing_liabilities(30)
# Out:
# 9407397613.929964

# %%
l.benefits_paid(0)
# Out:
# 0.0

# %%
l.benefits_paid(1)
# Out:
# 83200000.0

# %%
l.get_interest_cost(1)
# Out:
# 63600000.0

# %%
l.get_service_cost(1)
# Out:
# 129364725.0

# %%
l.get_closing_liabilities(0)
# Out:
# 1060000000.0

# %%
cash = Cash()
can_equity = CanEquity()
us_equity = USEquity()
em_equity = EMEquity()
id_equity = IDEquity()
fixed_income = FixedIncome()
private_equity = PrivateEquity()
infrastrucutre = Infrastructure()
real_estate = RealEstate()

a = AssetAlloc(
    [
        (cash, 0.03),
        (can_equity, 0.09),
        (us_equity, 0.09),
        (em_equity, 0.04),
        (id_equity, 0.05),
        (fixed_income, 0.27),
        (private_equity, 0.13),
        (infrastructure, 0.13),
        (real_estate, 0.15),

    ]
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cash = Cash()
#       2 can_equity = CanEquity()
#       3 us_equity = USEquity()
#       4 em_equity = EMEquity()
#
# TypeError: Asset.__init__() missing 5 required positional arguments: 'name', 'expected_return', 'variance', 'liquidity', and 'asset_class'
